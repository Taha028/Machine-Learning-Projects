# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Placement_Dataset.csv")
data
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
data.shape
# Out:
# (215, 15)

# %%
data.isnull().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
data.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %% [markdown]
# # Two Types Of Handling
#
# # Imputation
#
# # Dropping

# %% [markdown]
# # Imputation Using Central Tedencies
#
# # Mean
#
# # Median
#
# # Mode

# %% [markdown]
# # Analyzing the Salary Column and Concluding Which Central Tendency Will Be Use

# %%
#As you can see the data is right skewed so we dont use mean as ,
#it is highlt effected by outlier so we use median here as its a best practice to,
#fill values with median and median is also not effected by outliers.

fig,ax = plt.subplots(figsize = (8,8))
sns.distplot(data["salary"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
#There is a very simple method to fill values 
data["salary"].fillna(data["salary"].median(),inplace = True)

# %%
#As you can see values are filed by median. if you do it with mean and mode same code just change central tedency.
data.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# # Imputation Group Wise

# %%
dataset = pd.read_csv("Placement_Dataset.csv")
dataset.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
#We first check what type of specialisations are in dataset

unique_val = data["specialisation"].unique()
unique_val
# Out:
# array(['Mkt&HR', 'Mkt&Fin'], dtype=object)

# %%
#Now we are going to impute value based on unique value 
#First checking what distribution they have

df = dataset[dataset["specialisation"]=="Mkt&HR"]
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 10      11      M  58.00  Central  61.00  Central  Commerce     60.00
# 12      13      F  47.00  Central  55.00   Others   Science     65.00
# 14      15      M  62.00  Central  47.00  Central  Commerce     50.00
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 202    203      M  70.00  Central  63.00  Central   Science     66.00
# 203    204      M  55.68   Others  61.33   Others  Commerce     56.87
# 208    209      F  43.00  Central  60.00   Others   Science     65.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
#ploting distribution

#Its is mostly normal but still right skewed so we use median on Mkt&HR group
fig,ax = plt.subplots(figsize = (8,8))
sns.distplot(df["salary"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
df1 = dataset[dataset["specialisation"]=="Mkt&Fin"]

# %%
#ploting distribution

#Its is mostly have outliers and right skewed so we use median on Mkt&HR group
fig,ax = plt.subplots(figsize = (8,8))
sns.distplot(df1["salary"])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %% [markdown]
# # Now imputing missing values

# %%
#Imputing Values by median
for i in unique_val:
    strr = []
    for j,k in data.iterrows():
        if k["specialisation"] == i:
            strr.append(k["salary"])
    med = np.median(strr)
    data.loc[data["specialisation"]==i,"salary"] = data.loc[data["specialisation"]==i,"salary"].fillna(med)

# %%
#If you have to calculate mean group wise
for i in unique_val:
    count = 0
    sal = 0
    for j,k in data.iterrows():
        if k["specialisation"] == i:
            if not pd.isnull(k["salary"]):
                sal+=k["salary"]
                count+=1
    if count>0:
        p = sal/count
        data.loc[data["specialisation"]==i,"salary"] = data.loc[data["specialisation"]==i,"salary"].fillna(sal)

# %%
#There are many Ways By which you can impute data like by using outliers,percentiles,quantiles and etc

# %% [markdown]
# # By Dropping Values

# %%
#Worst decison do as it will lead to loss data
datta = pd.read_csv("Placement_Dataset.csv")
datta
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
datta = datta.dropna(how = "any")

# %%
datta.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
datta.shape
# Out:
# (148, 15)
